# %%
import pandas as pd
df = pd.read_csv('../data/interim/cleaned_matches.csv')
df.head()
# Out:
#    match_id        date competition  season home_team away_team  home_goals  \
# 0         1  1872-11-30    Friendly    1872  Scotland   England         0.0
# 1         2  1873-03-08    Friendly    1873   England  Scotland         4.0
# 2         3  1874-03-07    Friendly    1874  Scotland   England         2.0
# 3         4  1875-03-06    Friendly    1875   England  Scotland         2.0
# 4         5  1876-03-04    Friendly    1876  Scotland   England         3.0
#
#    away_goals result    venue  neutral
# 0         0.0      D  Glasgow    False
# 1         2.0      H   London    False
# 2         1.0      H  Glasgow    False
# 3         2.0      D   London    False
# 4         0.0      H  Glasgow    False

# %%
import pandas as pd
teams = pd.read_csv(
    "../data/raw/teams/teams.csv"
)
print(teams.shape)
print(teams.columns.tolist())
teams.head()
# Out:
# (48, 136)
# ...
